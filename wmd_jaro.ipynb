# %%
import gensim
from gensim.models import word2vec
from gensim.similarities import WmdSimilarity

import csv
import numpy as np
import pandas as pd
import jieba
import Levenshtein

# %%
csv_file = 'data/power-facts.csv'
case_id = '44bc15c0-83b6-44de-8017-0d682537c63a'
df = readData(csv_file)
topn = 10

# %%
def readData(csv_file):
    '''
    Inputs:
        csv_file: csv文件路徑
    Outputs:
        df: 案例集合的dataframe格式
    '''
    df = pd.read_csv(csv_file)
    return df

# %%
def segWithDict(case_list):
    userdict = 'data/userdict.txt'
    stopwords = [line.strip() for line in open('data/stopwords.txt', 'r', encoding='utf-8').readlines()]
    stopwords2 = ['\n','\r','\r\n']

    fact_list = []
    tmp = []
    
    for i, cases in enumerate(case_list):
        seg = jieba.cut(cases[4], cut_all=False, HMM=True)
        seg_item = ' '.join(seg)
        tmp.append(seg_item)
        fact_list.append(tmp[i].split(' '))

    corpus = [[]for i in range(len(fact_list))] # 此為 word_list_sep[i] == ['w1','w2', ...] list格式
    
    jieba.load_userdict(userdict)
    
    for i in range(len(fact_list)):
        for j, word in enumerate(fact_list[i]):
            if word not in stopwords and word not in stopwords2:
                corpus[i].append(word)
    return corpus

# %%
def getCaseList(case_id,counts, case_list, df1):
    # print('case_list[0] : ', case_list[0])
    corpus = segWithDict(case_list)
    model = word2vec.Word2Vec.load('models/low_1000.model')
    instance = WmdSimilarity(corpus, model, counts)
    idx = [cases[0] for cases in case_list].index(case_id)
#     print('原案件：')
#     print(case_list[idx][2])
#     print(case_list[idx][3])
#     print(case_list[idx][4])
    query = corpus[idx]
#     print('分詞後的 query:', query)

    sims = instance[query]
#     for sim in sims:
#         print(sim)
    result_list = []
    
    for sim in sims:
#         print('###########################')
#         print(sim[1]) # similarity
#         print(case_list[sim[0]][3]) # name 
#         print(case_list[sim[0]][4]) # illega_facts
        tmp = []
        tmp.append(case_list[sim[0]][0]) # case_id
        tmp.append(case_list[sim[0]][4])
        result_list.append(tmp)
        
    return result_list

# %%
'''示例：   
    r_df=by_jaro_winkler('c0814c02-0504-46fe-ac8c-e6087d4cd01f')
    print(r_df)
'''
def  recommender_by_id(case_id,df1):
    r_df=pd.DataFrame()
    recommander=dict()

    df_tmp = df[(df.CASE_ID==case_id)]
    target_line=df_tmp.ILLEGAL_FACTS.to_string(index=False).strip()
    for index,row in df1.iterrows():
        sim=Levenshtein.jaro_winkler(target_line, row.values[4].strip())
        recommander[row.values[0]]=sim
    for i,pre in enumerate(sorted(recommander.items(),key=lambda x:x[1],reverse=True)):
#     for i,pre in enumerate(sorted(recommander.items(),key=lambda x:x[1],reverse=True)[0:topn]):
        index=df[df['CASE_ID']==pre[0]].index.values[0]
#         待推薦案例本身也是類案
#         if case_id==pre[0]:
#             pass
#             continue 
        r_df_len=r_df.shape[0]
        r_df=r_df.append(df.iloc[index,[0,4]])
    r_df.columns=['CASE_ID', 'ILLEGAL_FACTS']
    return r_df

def by_jaro_winkler(case_id):
    power_id=df[df['CASE_ID'] == case_id].POWER_ID.to_string(index=False).strip()
    df1=df[df['POWER_ID'] == power_id]
    df_len=df1.shape[0]
    if df_len>=20:
        r_df=recommender_by_id(case_id,df1)
    else:
        print("案件数量太少，无法推荐")
        r_df=None
    return r_df

# %%
jaroDf = by_jaro_winkler(case_id)
jaroDf.reset_index(level=0, inplace=True)
jaroDf.drop(['index'], axis=1, inplace=True)
jaroDf['SCORE1'] = ''
for i in range(len(jaroDf)):
    score = 200-i*10
    if score >= 0:
        jaroDf.loc[i, 'SCORE1'] = score
    else:
        jaroDf.loc[i, 'SCORE1'] = 0
# print(len(jaroDf))
jaroDf
# Out:
#                                   CASE_ID              ILLEGAL_FACTS SCORE1
# 0    0f1812dd-fb6a-4ddb-bfe9-34fe03351cfc    在京密引水渠温泉倒虹吸下游左岸20米处水域垂钓    200
# 1    ec74500e-f252-4f61-9b1c-408582324bff   在京密引水渠温泉倒虹吸下游右岸300米处水域垂钓    190
# 2    b4227d87-ac64-496e-9881-3fbb1639c3eb   在京密引水渠温泉倒虹吸下游左岸300米处水域垂钓    180
# 3    3463cea2-169a-42e8-9c11-899e9d213cfc   在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼    170
# 4    44bc15c0-83b6-44de-8017-0d682537c63a   在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼    160
# 5    19c405d6-d889-4b17-95d2-52dc2de73aae   在京密引水渠温泉倒虹吸下游左岸500米处水域游泳    150
# 6    5edb4506-05ee-48e7-9984-52563224208a   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓    140
# 7    e33b075e-75fd-4990-89c1-3a07c6c73bc8   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓    130
# 8    e27c2c3f-e53f-42b9-b22b-13e0c07fc4ff   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓    120
# 9    c91f3c96-6f5f-4e28-89a6-466b408be0af     在京密引水渠温泉倒虹吸下游左岸5米处水域游泳    110
# 10   c8a785a6-c73f-453c-a428-ac6daa8c717f     在京密引水渠温泉倒虹吸下游左岸5米处水域游泳    100
# 11   539415b0-9a1b-4b69-8531-156ed77dd927   在京密引水渠横桥倒虹吸下游左岸100米处水域垂钓     90
# 12   25947d00-21d2-471a-b9a8-78305798a707    在京密引水渠宏丰小学下游左岸100米处水域捕鱼     80
# 13   f61a3e13-f0cc-4e08-8137-5b259caf4a07   在京密引水渠横桥倒虹吸下游左岸150米处水域垂钓     70
# 14   ae9b6bcf-d0b0-45a2-8743-2235af21f353   在京密引水渠柳林倒虹吸上游左岸700米处水域垂钓     60
# 15   98d9aef8-2849-43fb-8b2c-c128091a8e0a     在京密引水渠冷泉桥下游左岸200米处水域垂钓     50
# 16   aa1b3985-e737-4921-9a4d-a6c7215132b3     在京密引水渠冷泉桥下游左岸100米处水域垂钓     40
# 17   e3d3027e-002d-4541-98da-9097b9ed205e   在京密引水渠东沙河倒虹吸上游左岸50米处水域垂钓     30
# 18   36625bf2-1173-428d-b2c8-bc83a76c09ee   在京密引水渠柳林倒虹吸上游左岸710米处水域垂钓     20
# 19   e2b29338-2ed6-4d9a-94e6-1f1726bd757b   在京密引水渠柳林倒虹吸上游左岸720米处水域垂钓     10
# 20   eb018215-e627-4fbb-846e-ba238523d89b     在京密引水渠阳坊桥下游右岸300米处水域垂钓      0
# 21   aa59fee6-e388-41d6-89cb-7680e00c7901     在京密引水渠北清路下游左岸100米处水域垂钓      0
# 22   39744e87-233c-47b7-bf70-d01adcf0d3d8     在京密引水渠寺上桥下游左岸200米处水域垂钓      0
# 23   2def4541-15d5-4416-8d4d-1fa357ee7be4     在京密引水渠纪窑桥下游左岸100米处水域垂钓      0
# 24   9ac49dae-17e7-4a30-b9ae-b5fd0094657e  在京密引水渠亮甲店小铁桥下游左岸300米处水域垂钓      0
# 25   fcc977fa-2c6c-4096-92ef-a565d88cc93a  在京密引水渠金家坟公路桥下游左岸300米处水域垂钓      0
# 26   3d9edcf6-db37-4090-a83a-06700925c90c    在京密引水渠张各庄桥下游左岸100米处水域垂钓      0
# 27   da6e2da0-1902-4bf9-863d-58f9074a9d19    在京密引水渠亮甲店桥下游左岸200米处水域垂钓      0
# 28   82fd3841-1061-4a74-95d2-98b667319a52    在京密引水渠峰山口闸下游左岸200米处水域垂钓      0
# 29   5a35c622-3166-413b-801f-f7f5a0edbea6     在京密引水渠秦城桥上游左岸100米处水域垂钓      0
# ..                                    ...                        ...    ...
# 90   16fa96c6-f317-4526-bfbf-a403bc549dfb       在京密引水渠西范各庄桥处水域垂钓\r\n      0
# 91   84684344-5668-4832-919f-17db94d01075       在京密引水渠西范各庄桥处水域垂钓\r\n      0
# 92   426f47c5-40cb-4d65-8ab9-6a671e553985       在京密引水渠红螺寺新桥处水域垂钓\r\n      0
# 93   c7d586f3-2696-4aaf-85b8-ef0d829a0979       在京密引水渠红螺寺新桥处水域垂钓\r\n      0
# 94   312db363-6583-4de6-94c9-b98fab110343     在京密引水渠北石槽大桥桥上处水域垂钓\r\n      0
# 95   92b46835-91d0-42bb-9738-dee985f8a2bc     在京密引水渠半壁店溢洪口桥处水域垂钓\r\n      0
# 96   8aad1bd9-aa77-4767-b127-5cabfca82676         在京密引水渠寺上桥处水域垂钓\r\n      0
# 97   ca6889a0-41c8-4762-ba77-95f69e906d36         在京密引水渠九厂桥处水域垂钓\r\n      0
# 98   4b948fe3-5896-4521-badf-a865ca8475c6         在京密引水渠九厂桥处水域垂钓\r\n      0
# 99   97f40b6a-f552-4c27-93c6-b9123e42beee         在京密引水渠寺上桥处水域垂钓\r\n      0
# 100  6c4ced03-3525-4cdb-81d5-8509259009dc         在京密引水渠寺上桥处水域垂钓\r\n      0
# 101  35835fe8-9d35-4654-a7e8-3089fb860fc6         在京密引水渠寺上桥处水域垂钓\r\n      0
# 102  e3123fb5-437f-4c94-b9ea-dcfa89425bfb         在京密引水渠天北桥处水域垂钓\r\n      0
# 103  f4abf6f7-a846-47f6-92ef-79759aa5cdb1        在京密引水渠天北路桥处水域垂钓\r\n      0
# 104  15208664-1e52-4cbe-b71f-d7b731a5f732        在京密引水渠天北路桥处水域垂钓\r\n      0
# 105  b3eccddd-1e21-4edf-a72d-65053f10ca82        在京密引水渠半壁店桥处水域垂钓\r\n      0
# 106  1526a421-98ef-4b89-bb67-1757665c8e23   京密引水渠史家桥大车桥右岸上游100米处水域垂钓      0
# 107  3456a489-7870-4cc7-b8c8-554959cba4c5      在怀柔水库进水闸上游右岸150米处水域垂钓      0
# 108  ae031259-5458-4858-bfe2-e66d5e42ed80        在怀柔水库西溢洪道东100米处水域垂钓      0
# 109  fab36428-1185-4439-bab8-1a90e1f16c83       在怀柔水库太阳观测站东500米处水域垂钓      0
# 110  bdf3a40b-f041-46e2-a21a-21c2f82f59d0       在怀柔水库太阳观测站东500米处水域垂钓      0
# 111  2b3cc17d-e5cd-4ee9-8948-49fa5cdad8b5         在怀柔水库西溢洪道东80米处水域垂钓      0
# 112  ce60c83f-6c99-46eb-9dad-3464e7cf8849         在怀柔水库峰山口闸北20米处水域垂钓      0
# 113  25bb00d8-a2db-4335-a819-f1d955971276        在怀柔水库郭家坞村东180米处水域垂钓      0
# 114  2a29d192-7087-486e-83a1-5cfcb9d6584b        在怀柔水库郭家坞村东160米处水域垂钓      0
# 115  297204e9-6cfe-4c2d-92e8-99bcfaae454c        在怀柔水库太阳观测站西20米处水域垂钓      0
# 116  7fdd84bd-d965-414b-81fe-761158b692a3        在怀柔水库西溢洪道西160米处水域垂钓      0
# 117  8c42c45b-58a7-446c-b391-486568d3d990        在怀柔水库太阳观测站西25米处水域垂钓      0
# 118  235f8975-4d17-42c0-b338-528f68711678        在怀柔水库太阳观测站内水域垂钓\r\n      0
# 119  57ba4e65-bed2-4d58-b523-5fb527d166b1        在怀柔水库太阳观测站内水域垂钓\r\n      0
#
# [120 rows x 3 columns]

# %%
df2 = pd.merge(jaroDf, wmDf)
df2['SCORE'] = df2['SCORE1']+df2['SCORE2']
df2['SCORE'] = df2['SCORE']/2
df2.drop(['SCORE1'], axis=1, inplace=True)
df2.drop(['SCORE2'], axis=1, inplace=True)
df2.sort_values('SCORE', ascending=False, inplace=True)
# df2.drop(['SCORE'], axis=1)
df2
# Out:
#                                   CASE_ID              ILLEGAL_FACTS SCORE
# 3    3463cea2-169a-42e8-9c11-899e9d213cfc   在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼   190
# 0    0f1812dd-fb6a-4ddb-bfe9-34fe03351cfc    在京密引水渠温泉倒虹吸下游左岸20米处水域垂钓   185
# 1    ec74500e-f252-4f61-9b1c-408582324bff   在京密引水渠温泉倒虹吸下游右岸300米处水域垂钓   185
# 2    b4227d87-ac64-496e-9881-3fbb1639c3eb   在京密引水渠温泉倒虹吸下游左岸300米处水域垂钓   185
# 4    44bc15c0-83b6-44de-8017-0d682537c63a   在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼   180
# 6    5edb4506-05ee-48e7-9984-52563224208a   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓   150
# 5    19c405d6-d889-4b17-95d2-52dc2de73aae   在京密引水渠温泉倒虹吸下游左岸500米处水域游泳   140
# 7    e33b075e-75fd-4990-89c1-3a07c6c73bc8   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓   140
# 8    e27c2c3f-e53f-42b9-b22b-13e0c07fc4ff   在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓   130
# 9    c91f3c96-6f5f-4e28-89a6-466b408be0af     在京密引水渠温泉倒虹吸下游左岸5米处水域游泳   115
# 10   c8a785a6-c73f-453c-a428-ac6daa8c717f     在京密引水渠温泉倒虹吸下游左岸5米处水域游泳   105
# 11   539415b0-9a1b-4b69-8531-156ed77dd927   在京密引水渠横桥倒虹吸下游左岸100米处水域垂钓    95
# 13   f61a3e13-f0cc-4e08-8137-5b259caf4a07   在京密引水渠横桥倒虹吸下游左岸150米处水域垂钓    80
# 12   25947d00-21d2-471a-b9a8-78305798a707    在京密引水渠宏丰小学下游左岸100米处水域捕鱼    70
# 14   ae9b6bcf-d0b0-45a2-8743-2235af21f353   在京密引水渠柳林倒虹吸上游左岸700米处水域垂钓    65
# 17   e3d3027e-002d-4541-98da-9097b9ed205e   在京密引水渠东沙河倒虹吸上游左岸50米处水域垂钓    55
# 18   36625bf2-1173-428d-b2c8-bc83a76c09ee   在京密引水渠柳林倒虹吸上游左岸710米处水域垂钓    30
# 19   e2b29338-2ed6-4d9a-94e6-1f1726bd757b   在京密引水渠柳林倒虹吸上游左岸720米处水域垂钓    30
# 15   98d9aef8-2849-43fb-8b2c-c128091a8e0a     在京密引水渠冷泉桥下游左岸200米处水域垂钓    25
# 16   aa1b3985-e737-4921-9a4d-a6c7215132b3     在京密引水渠冷泉桥下游左岸100米处水域垂钓    20
# 20   eb018215-e627-4fbb-846e-ba238523d89b     在京密引水渠阳坊桥下游右岸300米处水域垂钓    15
# 24   9ac49dae-17e7-4a30-b9ae-b5fd0094657e  在京密引水渠亮甲店小铁桥下游左岸300米处水域垂钓    10
# 25   fcc977fa-2c6c-4096-92ef-a565d88cc93a  在京密引水渠金家坟公路桥下游左岸300米处水域垂钓     5
# 91   84684344-5668-4832-919f-17db94d01075       在京密引水渠西范各庄桥处水域垂钓\r\n     0
# 92   426f47c5-40cb-4d65-8ab9-6a671e553985       在京密引水渠红螺寺新桥处水域垂钓\r\n     0
# 83   8c5184f6-2ca9-470f-b8d0-441cb06f642a   在京密引水渠前沙涧山洪桥上游右岸20米处水域垂钓     0
# 90   16fa96c6-f317-4526-bfbf-a403bc549dfb       在京密引水渠西范各庄桥处水域垂钓\r\n     0
# 89   0a28ea1d-cd67-4084-8726-0be9c346ab01      在京密引水渠京包高架桥下处水域垂钓\r\n     0
# 88   1132033e-e8ad-402c-85b8-af90aaeb448a       在京密引水渠跃进桥上游184米处水域游泳     0
# 87   81fd0fde-e64a-4023-92e5-637a3026df94       在京密引水渠跃进桥上游182米处水域游泳     0
# ..                                    ...                        ...   ...
# 27   da6e2da0-1902-4bf9-863d-58f9074a9d19    在京密引水渠亮甲店桥下游左岸200米处水域垂钓     0
# 26   3d9edcf6-db37-4090-a83a-06700925c90c    在京密引水渠张各庄桥下游左岸100米处水域垂钓     0
# 23   2def4541-15d5-4416-8d4d-1fa357ee7be4     在京密引水渠纪窑桥下游左岸100米处水域垂钓     0
# 22   39744e87-233c-47b7-bf70-d01adcf0d3d8     在京密引水渠寺上桥下游左岸200米处水域垂钓     0
# 21   aa59fee6-e388-41d6-89cb-7680e00c7901     在京密引水渠北清路下游左岸100米处水域垂钓     0
# 44   848a351d-fc50-4540-84a8-a6a42dd5ab1d    在京密引水渠良善庄桥下游左岸120米处水域垂钓     0
# 45   d10945ea-d9a5-4681-9146-1024436d798c   在京密引水渠亮甲店小铁桥下游左岸10米处水域垂钓     0
# 46   0f5718b4-ad27-4543-a975-93311828d9c1   在京密引水渠秦城公路桥上游左岸200米处水域垂钓     0
# 58   8b82b730-4f8a-40ff-89ed-c736c4026b3c     在京密引水渠良善庄桥下游左岸150处水域垂钓     0
# 68   690a0fbd-a68b-4f43-90c9-bf8a65d0d08e       在京密引水渠聚贤桥上游右岸3米处水域垂钓     0
# 67   a79e077b-60d4-4125-93a0-72d514ecaeb5       在京密引水渠香堂桥上游左岸50米水域垂钓     0
# 66   c3be7b0e-02f4-40d8-be68-a95eebf08582    在京密引水渠峰山口闸下游右岸160米处水域垂钓     0
# 65   df992f4f-edda-45a8-af95-e936dfb662ee    在京密引水渠兴寿公路桥下游右岸10米处水域垂钓     0
# 64   f0eca474-b639-47eb-b656-df5088d29e0d    在京密引水渠红螺寺旧桥下游左岸15米处水域垂钓     0
# 63   888a5c0c-2b96-43e6-86e2-e3ecf2889d81    在京密引水渠西北旺桥上游右岸400米处水域垂钓     0
# 62   8477e1fd-0643-498a-ae89-c3024360304c    在京密引水渠良善庄桥下游左岸125米处水域垂钓     0
# 61   8445f1c3-d2dd-40eb-a324-e8c29b1bfe7e    在京密引水渠亮甲店小铁桥下游左岸20米水域垂钓     0
# 59   f0dcd77a-c469-4de0-ad34-9038dfc9f6d7     在京密引水渠良善庄桥下游右岸10米处水域垂钓     0
# 57   3809af43-d734-4890-950b-52e605f49160     在京密引水渠阳坊桥下游右岸120米处水域垂钓     0
# 47   d91084f3-83fe-4654-8fb4-281a85c4e95f      在京密引水渠南丰桥上游左岸10米处水域垂钓     0
# 56   4d785e32-303f-40d8-b0af-241183d36932     在京密引水渠秦城桥上游左岸150米处水域垂钓     0
# 55   37059a90-4eda-475a-91e2-9987d7efdb8d  在京密引水渠王史山大车桥上游左岸200米处水域垂钓     0
# 54   3b279091-d89f-4743-9965-4775248388da  在京密引水渠前沙涧山洪桥下游右岸100米处水域垂钓     0
# 53   58cc2ae3-7680-4c8b-8ff0-51ab1799952b  在京密引水渠白家疃山洪桥上游右岸300米处水域垂钓     0
# 52   5367ddb0-950c-4445-bc00-ad696b9266dd   在京密引水渠八口大车桥下游右岸500米处水域垂钓     0
# 51   bf868d4f-5ce4-4b11-8a82-5df2176726b1      在京密引水渠聚贤桥下游右岸50米处水域垂钓     0
# 50   107afef7-d202-4117-acb1-6d0ec8fabd74   在京密引水渠秦城公路桥上游左岸400米处水域垂钓     0
# 49   a5787c10-268f-45eb-a356-79302858712c      在京密引水渠安泗桥上游左岸10米处水域垂钓     0
# 48   1646eb13-e6f6-4a74-a108-c553c1642537      在京密引水渠聚贤桥上游左岸10米处水域垂钓     0
# 119  57ba4e65-bed2-4d58-b523-5fb527d166b1        在怀柔水库太阳观测站内水域垂钓\r\n     0
#
# [120 rows x 3 columns]

# %%
result_list = df2.values.tolist()
for i in range(topn+1):
    print('=======================',i,'===========================')
    print(result_list[i][0])
    print(result_list[i][1], '\n')
# Out:
# ======================= 0 ===========================
# 3463cea2-169a-42e8-9c11-899e9d213cfc
# 在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼
#
# ======================= 1 ===========================
# 0f1812dd-fb6a-4ddb-bfe9-34fe03351cfc
# 在京密引水渠温泉倒虹吸下游左岸20米处水域垂钓
#
# ======================= 2 ===========================
# ec74500e-f252-4f61-9b1c-408582324bff
# 在京密引水渠温泉倒虹吸下游右岸300米处水域垂钓
#
# ======================= 3 ===========================
# b4227d87-ac64-496e-9881-3fbb1639c3eb
# 在京密引水渠温泉倒虹吸下游左岸300米处水域垂钓
#
# ======================= 4 ===========================
# 44bc15c0-83b6-44de-8017-0d682537c63a
# 在京密引水渠温泉倒虹吸下游左岸300米处水域捕鱼
#
# ======================= 5 ===========================
# 5edb4506-05ee-48e7-9984-52563224208a
# 在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓
#
# ======================= 6 ===========================
# 19c405d6-d889-4b17-95d2-52dc2de73aae
# 在京密引水渠温泉倒虹吸下游左岸500米处水域游泳
#
# ======================= 7 ===========================
# e33b075e-75fd-4990-89c1-3a07c6c73bc8
# 在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓
#
# ======================= 8 ===========================
# e27c2c3f-e53f-42b9-b22b-13e0c07fc4ff
# 在京密引水渠温泉倒虹吸下游右岸600米处水域垂钓
#
# ======================= 9 ===========================
# c91f3c96-6f5f-4e28-89a6-466b408be0af
# 在京密引水渠温泉倒虹吸下游左岸5米处水域游泳
#
# ======================= 10 ===========================
# c8a785a6-c73f-453c-a428-ac6daa8c717f
# 在京密引水渠温泉倒虹吸下游左岸5米处水域游泳

# %%
def case_recommernder(case_id):
    illegal_fact=df[(df.CASE_ID==case_id)].ILLEGAL_FACTS.to_string(index=False).strip()
    power_id,power_name,case_list，counts,df1=getPowerlist(illegal_fact)

# %%
from law Predict import LawPredictor
def getPowerlist(illegal_fact):
    test=LawPredictor.PowerClassifier('anjian')
    illegal_facts=df[df['CASE_ID']==case_id].ILLEGAL_FACTS.to_string(index=False).strip()
    power_id,power_name=test.power_predict(fact)
    df1 = df[(df.POWER_ID==power_id)]
    counts = df1.count().tolist()[0]
#     print('同案由下案件數：', counts)
    case_list = df1.values.tolist()
    return power_id,power_name,case_list,counts,df1

# %%
def wmn_recommender(case_list):
    wmn_list=getCaseList(case_id,counts, case_list, df1)
